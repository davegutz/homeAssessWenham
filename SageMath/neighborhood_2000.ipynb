# %%
# %load_ext rpy2.ipython
# %R a <- c(1,2,3); print(a*2)
# Out:
# [1] 2 4 6
# array([2., 4., 6.])

# %%
# %%R
# # This whole cell is interpreted as R code
# a <- c(1,2,3)
# print(a*2)
# plot(1:10) # Plotting works directly in the notebook with this method
# Out:
# [1] 2 4 6

# %%
# %%R
#
# # Real Estate analysis
# # 15-Sep-2024
#
# # SETUP ####
# # load packages
# library(lubridate)
# library(readxl)
# library(ggplot2)
# library(tidyr)
# library(effects)
# library(dplyr)
# library(zoo) # rollmean

# %%
# %%R
#
# # Import Data
# D <- read.csv("all2000_20230127.csv")
# D$Total.Value <- as.numeric(gsub("[$,]", "", D$Total.Value))
# D <- D[!is.na(D$Fin.area), ]
# D <- D[!is.na(D$Total.Value), ]

# %%
# %%R
#
# # Separate types
# Ra <- D[D$Type=='RANCH', ]
# Cp <- D[D$Type=='CAPE', ]
# Co <- D[D$Type=='COLONIAL', ]
# Sl <- D[D$Type=='SPLIT LEVL', ]
#
# plot(Total.Value ~ Fin.area, data=D)
# plot(Total.Value ~ Lot.size, data=D)
# plot(Total.Value ~ Fin.area, data=Ra)
# plot(Total.Value ~ Lot.size, data=Ra)

# %%
# %%R
#
# ######### All
# lm_faD <- lm(Total.Value ~ Fin.area, data=D)
# summary(lm_faD)
# plot(allEffects(lm_faD))
#
# glm_faD <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths + Type, family=gaussian, data=D)
# summary(glm_faD)
# plot(allEffects(glm_faD))
#
# #newdata=data.frame(nickel=c(80, 90, 99, 100, 101, 110))
# #predict(glm_nickel, newdata, type="response") # odds of getting migraine given levels of nickel intake (ug)
#
# ######### Ranch
# lm_faRa <- lm(Total.Value ~ Fin.area, data=Ra)
# summary(lm_faRa)
# plot(allEffects(lm_faRa))
#
# plot(Total.Value ~ Fin.area, data=Ra)
# abline(lm_faRa)
#
#
# glm_Ra <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths, family=gaussian, data=Ra)
# summary(glm_Ra)
# plot(allEffects(glm_Ra))
#
# new_fa=data.frame(Fin.area=c(0, 5000))
# new_Ra=predict(lm_faRa, new_fa, type="response")
#
# ######### Cape
# lm_faCp <- lm(Total.Value ~ Fin.area, data=Cp)
# summary(lm_faCp)
# plot(allEffects(lm_faCp))
#
# glm_Cp <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths, family=gaussian, data=Cp)
# summary(glm_Cp)
# plot(allEffects(glm_Cp))
#
# ######### Colonial
# lm_faCo <- lm(Total.Value ~ Fin.area, data=Co)
# summary(lm_faCo)
# plot(allEffects(lm_faCo))
#
# glm_Co <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths, family=gaussian, data=Co)
# summary(glm_Co)
# plot(allEffects(glm_Co))
#
# ######### Split Level
# lm_faSl <- lm(Total.Value ~ Fin.area, data=Sl)
# summary(lm_faSl)
# plot(allEffects(lm_faSl))
#
# glm_Sl <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths, family=gaussian, data=Sl)
# summary(glm_Sl)
# plot(allEffects(glm_Sl))
#
# #############Summarize
#
# # Create an empty plot
# plot(Ra$Fin.area, Ra$Total.Value, type="n", xlim=c(500, 5500), ylim=c(200000, 1200000),
#      xlab="Finished Area, sqft", ylab="Total Assesed Value, $", main="Wenham Neighborhood 2000")
# lines(Ra$Fin.area, Ra$Total.Value, type="p", pch=1, col="red")
# abline(lm_faRa, col="red")
# lines(Cp$Fin.area, Cp$Total.Value, type="p", pch=2, col="blue")
# abline(lm_faCp, col="blue")
# lines(Co$Fin.area, Co$Total.Value, type="p", pch=3, col="green")
# abline(lm_faCo, col="green")
# lines(Sl$Fin.area, Sl$Total.Value, type="p", pch="S", col="black")
# abline(lm_faSl, col="black")
# legend("topleft", legend=c("Ranch", "Cape", "Colonial", "Split Level"), col=c("red", "blue", "green", "black"), lty=1)
# Out:
# R[write to console]: Error in grid::grid.pretty(range.labels) :
#   non-finite axis extents [GEPretty(-inf,inf, n=5)]
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In qt(1 - (1 - confidence.level)/2, df = df.residual) :
# R[write to console]:  NaNs produced
#
# R[write to console]: 2:
# R[write to console]: In qt(1 - (1 - confidence.level)/2, df = df.residual) :
# R[write to console]:  NaNs produced
#
# R[write to console]: 3:
# R[write to console]: In qt(1 - (1 - confidence.level)/2, df = df.residual) :
# R[write to console]:  NaNs produced
#
# R[write to console]: 4:
# R[write to console]: In qt(1 - (1 - confidence.level)/2, df = df.residual) :
# R[write to console]:  NaNs produced
#
# R[write to console]: 5:
# R[write to console]: In min(x) :
# R[write to console]:  no non-missing arguments to min; returning Inf
#
# R[write to console]: 6:
# R[write to console]: In max(x) :
# R[write to console]:  no non-missing arguments to max; returning -Inf
# Error in grid::grid.pretty(range.labels) :
#   non-finite axis extents [GEPretty(-inf,inf, n=5)]
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/SageMath/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/rpy2/ipython/rmagic.py:268, in RMagics.eval(self, code)
#     266 try:
#     267     # Need the newline in case the last line in code is a comment.
# --> 268     value, visible = ro.r("withVisible({%s\n})" % code)
#     269 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     270     # Otherwise next return seems to have copy of error.
#
# File ~/SageMath/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/rpy2/robjects/__init__.py:438, in R.__call__(self, string)
#     437 p = rinterface.parse(string)
# --> 438 res = self.eval(p)
#     439 return conversion.rpy2py(res)
#
# File ~/SageMath/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/rpy2/robjects/functions.py:198, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     197         kwargs[r_k] = v
# --> 198 return (super(SignatureTranslatedFunction, self)
#     199         .__call__(*args, **kwargs))
#
# File ~/SageMath/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/rpy2/robjects/functions.py:125, in Function.__call__(self, *args, **kwargs)
#     124         new_kwargs[k] = conversion.py2rpy(v)
# --> 125 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     126 res = conversion.rpy2py(res)
#
# File ~/SageMath/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#
# File ~/SageMath/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/rpy2/rinterface.py:680, in SexpClosure.__call__(self, *args, **kwargs)
#     679     if error_occured[0]:
# --> 680         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     681 return res
#
# RRuntimeError: Error in grid::grid.pretty(range.labels) :
#   non-finite axis extents [GEPretty(-inf,inf, n=5)]
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 get_ipython().run_cell_magic('R', '', '\n######### All\nlm_faD <- lm(Total.Value ~ Fin.area, data=D)\nsummary(lm_faD)\nplot(allEffects(lm_faD))\n\nglm_faD <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths + Type, family=gaussian, data=D)\nsummary(glm_faD)\nplot(allEffects(glm_faD))\n\n#newdata=data.frame(nickel=c(80, 90, 99, 100, 101, 110))\n#predict(glm_nickel, newdata, type="response") # odds of getting migraine given levels of nickel intake (ug)\n\n######### Ranch\nlm_faRa <- lm(Total.Value ~ Fin.area, data=Ra)\nsummary(lm_faRa)\nplot(allEffects(lm_faRa))\n\nplot(Total.Value ~ Fin.area, data=Ra)\nabline(lm_faRa)\n\n\nglm_Ra <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths, family=gaussian, data=Ra)\nsummary(glm_Ra)\nplot(allEffects(glm_Ra))\n\nnew_fa=data.frame(Fin.area=c(0, 5000))\nnew_Ra=predict(lm_faRa, new_fa, type="response")\n\n######### Cape\nlm_faCp <- lm(Total.Value ~ Fin.area, data=Cp)\nsummary(lm_faCp)\nplot(allEffects(lm_faCp))\n\nglm_Cp <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths, family=gaussian, data=Cp)\nsummary(glm_Cp)\nplot(allEffects(glm_Cp))\n\n######### Colonial\nlm_faCo <- lm(Total.Value ~ Fin.area, data=Co)\nsummary(lm_faCo)\nplot(allEffects(lm_faCo))\n\nglm_Co <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths, family=gaussian, data=Co)\nsummary(glm_Co)\nplot(allEffects(glm_Co))\n\n######### Split Level\nlm_faSl <- lm(Total.Value ~ Fin.area, data=Sl)\nsummary(lm_faSl)\nplot(allEffects(lm_faSl))\n\nglm_Sl <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths, family=gaussian, data=Sl)\nsummary(glm_Sl)\nplot(allEffects(glm_Sl))\n\n#############Summarize\n\n# Create an empty plot\nplot(Ra$Fin.area, Ra$Total.Value, type="n", xlim=c(500, 5500), ylim=c(200000, 1200000), \n     xlab="Finished Area, sqft", ylab="Total Assesed Value, $", main="Wenham Neighborhood 2000")\nlines(Ra$Fin.area, Ra$Total.Value, type="p", pch=1, col="red")\nabline(lm_faRa, col="red")\nlines(Cp$Fin.area, Cp$Total.Value, type="p", pch=2, col="blue")\nabline(lm_faCp, col="blue")\nlines(Co$Fin.area, Co$Total.Value, type="p", pch=3, col="green")\nabline(lm_faCo, col="green")\nlines(Sl$Fin.area, Sl$Total.Value, type="p", pch="S", col="black")\nabline(lm_faSl, col="black")\nlegend("topleft", legend=c("Ranch", "Cape", "Colonial", "Split Level"), col=c("red", "blue", "green", "black"), lty=1)\n')
#
# File ~/SageMath/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/SageMath/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/rpy2/ipython/rmagic.py:783, in RMagics.R(self, line, cell, local_ns)
#     781     if not e.stdout.endswith(e.err):
#     782         print(e.err)
# --> 783     raise e
#     784 finally:
#     785     if self.device in ['png', 'svg']:
#
# File ~/SageMath/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/rpy2/ipython/rmagic.py:763, in RMagics.R(self, line, cell, local_ns)
#     761         return_output = False
#     762 else:
# --> 763     text_result, result, visible = self.eval(code)
#     764     text_output += text_result
#     765     if visible:
#
# File ~/SageMath/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/rpy2/ipython/rmagic.py:272, in RMagics.eval(self, code)
#     269 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     270     # Otherwise next return seems to have copy of error.
#     271     warning_or_other_msg = self.flush()
# --> 272     raise RInterpreterError(code, str(exception),
#     273                             warning_or_other_msg)
#     274 text_output = self.flush()
#     275 return text_output, value, visible[0]
#
# RInterpreterError: Failed to parse and evaluate line '\n######### All\nlm_faD <- lm(Total.Value ~ Fin.area, data=D)\nsummary(lm_faD)\nplot(allEffects(lm_faD))\n\nglm_faD <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths + Type, family=gaussian, data=D)\nsummary(glm_faD)\nplot(allEffects(glm_faD))\n\n#newdata=data.frame(nickel=c(80, 90, 99, 100, 101, 110))\n#predict(glm_nickel, newdata, type="response") # odds of getting migraine given levels of nickel intake (ug)\n\n######### Ranch\nlm_faRa <- lm(Total.Value ~ Fin.area, data=Ra)\nsummary(lm_faRa)\nplot(allEffects(lm_faRa))\n\nplot(Total.Value ~ Fin.area, data=Ra)\nabline(lm_faRa)\n\n\nglm_Ra <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths, family=gaussian, data=Ra)\nsummary(glm_Ra)\nplot(allEffects(glm_Ra))\n\nnew_fa=data.frame(Fin.area=c(0, 5000))\nnew_Ra=predict(lm_faRa, new_fa, type="response")\n\n######### Cape\nlm_faCp <- lm(Total.Value ~ Fin.area, data=Cp)\nsummary(lm_faCp)\nplot(allEffects(lm_faCp))\n\nglm_Cp <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths, family=gaussian, data=Cp)\nsummary(glm_Cp)\nplot(allEffects(glm_Cp))\n\n######### Colonial\nlm_faCo <- lm(Total.Value ~ Fin.area, data=Co)\nsummary(lm_faCo)\nplot(allEffects(lm_faCo))\n\nglm_Co <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths, family=gaussian, data=Co)\nsummary(glm_Co)\nplot(allEffects(glm_Co))\n\n######### Split Level\nlm_faSl <- lm(Total.Value ~ Fin.area, data=Sl)\nsummary(lm_faSl)\nplot(allEffects(lm_faSl))\n\nglm_Sl <- glm(Total.Value ~ Fin.area + Lot.size + Beds + Baths, family=gaussian, data=Sl)\nsummary(glm_Sl)\nplot(allEffects(glm_Sl))\n\n#############Summarize\n\n# Create an empty plot\nplot(Ra$Fin.area, Ra$Total.Value, type="n", xlim=c(500, 5500), ylim=c(200000, 1200000), \n     xlab="Finished Area, sqft", ylab="Total Assesed Value, $", main="Wenham Neighborhood 2000")\nlines(Ra$Fin.area, Ra$Total.Value, type="p", pch=1, col="red")\nabline(lm_faRa, col="red")\nlines(Cp$Fin.area, Cp$Total.Value, type="p", pch=2, col="blue")\nabline(lm_faCp, col="blue")\nlines(Co$Fin.area, Co$Total.Value, type="p", pch=3, col="green")\nabline(lm_faCo, col="green")\nlines(Sl$Fin.area, Sl$Total.Value, type="p", pch="S", col="black")\nabline(lm_faSl, col="black")\nlegend("topleft", legend=c("Ranch", "Cape", "Colonial", "Split Level"), col=c("red", "blue", "green", "black"), lty=1)\n'.
# R error message: 'Error in grid::grid.pretty(range.labels) : \n  non-finite axis extents [GEPretty(-inf,inf, n=5)]'
